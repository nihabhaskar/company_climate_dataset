# %%
import collections
from math import log
import sys
import numpy as np
import sys
import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %%
dataset = pd.read_csv('company_climate_dataset.csv')

# %%
dataset
# Out:
#                                        company headquarters_country  \
# 0                            Alphabet (Google)        United States
# 1                                    Microsoft        United States
# 2                              Meta (Facebook)        United States
# 3                                        Tesla        United States
# 4                                        Apple        United States
# 5                                       Amazon        United States
# 6   Taiwan Semiconductor Manufacturing Company               Taiwan
# 7                                       Nvidia        United States
# 8                                      Tencent                China
# 9                                      Samsung          South Korea
# 10                                     Alibaba                China
# 11                                    Broadcom        United States
# 12                                       Cisco        United States
# 13                                ASML Holding          Netherlands
# 14                                      Oracle        United States
# 15                                       Adobe        United States
# 16                                       Intel        United States
# 17                                    Qualcomm        United States
# 18                                         AMD        United States
# 19                           Texas Instruments        United States
# 20                                     Meituan                China
# 21                                         IBM        United States
# 22                                  Salesforce        United States
# 23                                         SAP              Germany
# 24                                      Intuit        United States
# 25                                        Sony                Japan
# 26             Automatic Data Processing (ADP)        United States
# 27                                  Servicenow        United States
# 28                           Applied Materials        United States
# 29                                      PayPal        United States
# 30                                     Keyence                Japan
# 31                                 Booking.com          Netherlands
# 32                      Jingdong Mall (JD.com)                China
# 33                              Analog Devices        United States
# 34                                     Netflix        United States
# 35                          Schneider Electric               France
# 36                                Lam Research        United States
# 37                      Tokyo Electron Limited                Japan
# 38                                     Equinix        United States
# 39                           Micron Technology        United States
# 40                                      Fiserv        United States
# 41                        Fidelity Investments        United States
# 42                         Activision Blizzard        United States
# 43                                     NetEase                China
# 44                                    SK Hynix          South Korea
# 45                              Block (Square)        United States
# 46                                        Uber        United States
# 47                          Palo Alto Networks        United States
# 48                                   Atlassian            Australia
# 49                             KLA Corporation        United States
# 50                    Marvell Technology, Inc.        United States
# 51                                     Foxconn               Taiwan
#
#         usa_state  num_employees  net_worth ghg_emissions_metric_tons  \
# 0      California         150028    1453.76                 9071847.4
# 1      Washington         182268    1893.24                    123704
# 2      California          71970     517.69                   7550000
# 3           Texas          70757     734.97                   1954000
# 4      California         154000    2223.03                  22600000
# 5      Washington         170000    1091.91                    unsure
# 6             NaN          56831     410.00                   7430000
# 7      California          22473     493.71                    105621
# 8             NaN         112771     431.30                   5111000
# 9             NaN         287439     300.00                  29518000
# 10            NaN         251462     237.72                   9514000
# 11     California          20000     237.89                     50988
# 12     California          79500     173.31                    174494
# 13            NaN          32016     219.21                    883900
# 14          Texas         132000     178.87                    369300
# 15     California          25988     183.56                554125.676
# 16     California         121100     171.78                   2890000
# 17     California          45000     146.24                   3943605
# 18     California          22500     156.65                     29916
# 19          Texas          31000     154.57                   1920000
# 20            NaN          46662      27.77                  10789.23
# 21       New York         282100     127.00                    880188
# 22     California          73541     158.87                   1096000
# 23            NaN         107415     165.53                    110000
# 24     California          14200     100.08                     23481
# 25            NaN         109700      45.00                   1392868
# 26     New Jersey          58000      86.41                    137714
# 27     California          16881      85.55                     24338
# 28     California          27000      94.31                    151300
# 29     California          26500      94.13                     24400
# 30            NaN           6602      91.86                      3268
# 31            NaN          19400      85.39                    118746
# 32            NaN         310000     149.30                2275935.69
# 33  Massachusetts          24700      79.54                    142209
# 34     California          12135      83.36                   1540000
# 35            NaN         166025      74.34                    294051
# 36     California          14100      67.33                    113482
# 37            NaN          12742      29.00                       169
# 38     California          10944      59.54                   2307600
# 39          Idaho          40000      75.86                   7141289
# 40      Wisconsin          44000      61.54                    191405
# 41  Massachusetts          65000      85.90                     10000
# 42     California           9500      60.78                    unsure
# 43            NaN          18129      64.89                  70633.03
# 44            NaN          22254      56.08                     99765
# 45     California           8521      46.23                    247900
# 46     California          29300      45.64                   3239552
# 47     California          11098      42.98                    unsure
# 48            NaN           5752      23.99                     70207
# 49     California          11300      50.07                   4834000
# 50       Delaware           6729      46.80                  11248370
# 51            NaN        1290000    5990.00                   5519742
#
#    ghg_emissions_year water_withdrawal_cubic_meters  water_withdrawal_year  \
# 0                2021                     11365.225                 2021.0
# 1                2021                          7657                 2020.0
# 2                2020                       3726000                 2021.0
# 3                2021                       2874904                 2020.0
# 4                2020                    5850817.83                 2020.0
# 5              unsure                     480000000                 2020.0
# 6                2020                      77000000                 2021.0
# 7                2021                        359901                 2019.0
# 8                2021                    3635172.35                 2020.0
# 9                2020                        142294                    NaN
# 10               2020                        unsure                 2021.0
# 11               2021                   2501573.435                 2021.0
# 12               2021                          2902                 2021.0
# 13               2021                       1041000                    NaN
# 14               2020                        unsure                    NaN
# 15               2019                        unsure                 2020.0
# 16               2020                      62736042                    NaN
# 17               2021                    3514127.57                 2020.0
# 18               2020                        151000                 2020.0
# 19               2020                      18560000                    NaN
# 20               2020                        unsure                    NaN
# 21               2020                        unsure                 2021.0
# 22               2021                   492103.5319                 2021.0
# 23               2021                        765000                    NaN
# 24               2020                        unsure                 2020.0
# 25               2020                      18742665                    NaN
# 26               2020                        unsure                    NaN
# 27               2020                        unsure                 2020.0
# 28               2020                       2035000                 2021.0
# 29               2021                        293000                    NaN
# 30               2020                        unsure                    NaN
# 31               2021                        unsure                    NaN
# 32               2020                        unsure                    NaN
# 33               2020                        unsure                    NaN
# 34               2021                        unsure                 2021.0
# 35               2021                       2072263                 2020.0
# 36               2020                    1327458.28                 2021.0
# 37               2021                          1195                    NaN
# 38               2021                        unsure                 2020.0
# 39               2020                      55195350                    NaN
# 40               2021                        unsure                    NaN
# 41               2020                        unsure                    NaN
# 42                NaN                        unsure                    NaN
# 43               2020                        unsure                 2020.0
# 44               2020                      95714000                    NaN
# 45               2020                        unsure                 2020.0
# 46               2020                       1013210                    NaN
# 47                NaN                        unsure                    NaN
# 48               2021                        unsure                    NaN
# 49               2020                        unsure                 2021.0
# 50               2021                       9190000                    NaN
# 51               2020                        unsure                    NaN
#
#    avg_annual_PUE  ... percent_renewable_energy money_in_renewables_USdollars  \
# 0             1.1  ...                      100                    3300000000
# 1           1.125  ...                      100                     200000000
# 2             1.1  ...                      100                    7400000000
# 3             NaN  ...                      100                        unsure
# 4          unsure  ...                      100                    4700000000
# 5             1.7  ...                       65                        unsure
# 6             NaN  ...                      7.6                      44000000
# 7             NaN  ...                   unsure                        unsure
# 8            1.25  ...                      > 0                        unsure
# 9             NaN  ...                      100                      not sure
# 10           1.13  ...                   unsure                        unsure
# 11            NaN  ...                   unsure                        unsure
# 12           1.05  ...                       85                     100000000
# 13            NaN  ...                       92                        unsure
# 14            1.5  ...                       59                        unsure
# 15         unsure  ...                      > 0                        unsure
# 16           1.06  ...                       82                      45000000
# 17           1.18  ...                       50                      36000000
# 18            NaN  ...                       71                        unsure
# 19            NaN  ...                    18.14                        unsure
# 20            NaN  ...                   unsure                        unsure
# 21           1.67  ...                     59.3                        unsure
# 22           1.39  ...                      100                        unsure
# 23         unsure  ...                      100                        unsure
# 24         unsure  ...                      100                        unsure
# 25         unsure  ...                   unsure                        unsure
# 26           1.69  ...                        0                        unsure
# 27         unsure  ...                      100                        unsure
# 28         unsure  ...                      100                        unsure
# 29           1.49  ...                       82                        unsure
# 30         unsure  ...                   unsure                        unsure
# 31         unsure  ...                      100                        799808
# 32            1.3  ...                   unsure                        unsure
# 33         unsure  ...                       53                        unsure
# 34         unsure  ...                      100                        unsure
# 35            NaN  ...                     50.6                     156543450
# 36            NaN  ...                       30                        unsure
# 37            NaN  ...                       50                        unsure
# 38           1.48  ...                     80.1                    3700000000
# 39         unsure  ...                   unsure                    1000000000
# 40           1.15  ...                     0.15                        unsure
# 41            1.3  ...                      > 0                        unsure
# 42         unsure  ...                      > 0                        unsure
# 43            1.3  ...                     37.4                        unsure
# 44         unsure  ...                   unsure                        unsure
# 45         unsure  ...                   unsure                      10000000
# 46         unsure  ...                       32                     800000000
# 47            NaN  ...                       10                        unsure
# 48         unsure  ...                      100                        unsure
# 49            NaN  ...                       46                        unsure
# 50            NaN  ...                      1.3                        unsure
# 51            NaN  ...                    12.45                        unsure
#
#    waste_generated_metric_tons waste_generated_year  \
# 0                        28864               2021.0
# 1                         3189               2021.0
# 2                       unsure                  NaN
# 3                    32877.282               2021.0
# 4                    16556.122               2020.0
# 5                   272155.422               2020.0
# 6                       unsure                  NaN
# 7                         2778               2021.0
# 8                       unsure                  NaN
# 9                      1181741               2020.0
# 10                      unsure                  NaN
# 11                    8688.108               2021.0
# 12                        5863               2020.0
# 13                        5878               2021.0
# 14                 621.4229077               2020.0
# 15                      unsure                  NaN
# 16                  375574.482               2020.0
# 17                        2948               2021.0
# 18                         488               2020.0
# 19                       41800               2020.0
# 20                      unsure                  NaN
# 21                       23000               2020.0
# 22                      unsure                  NaN
# 23                         261               2021.0
# 24                 460.7781803               2020.0
# 25                   46594.823               2020.0
# 26                      unsure                  NaN
# 27                      unsure                  NaN
# 28                      8286.9               2020.0
# 29                      unsure                  NaN
# 30                         136               2020.0
# 31                      unsure                  NaN
# 32                    25768.96               2020.0
# 33                        3042               2020.0
# 34                      unsure                  NaN
# 35                      136816               2021.0
# 36                        8306               2020.0
# 37                       14997               2021.0
# 38                      unsure                  NaN
# 39                  202286.633               2020.0
# 40                      unsure                  NaN
# 41                      unsure                  NaN
# 42                      unsure                  NaN
# 43                        6122               2020.0
# 44                      572134               2020.0
# 45                      unsure                  NaN
# 46                      unsure                  NaN
# 47                      unsure                  NaN
# 48                         124               2021.0
# 49                      unsure                  NaN
# 50                      unsure                  NaN
# 51                      unsure                  NaN
#
#    highest_leed_certification  ev_charging_ports carbon_neutral_shipments  \
# 0                    platinum                yes                      yes
# 1                    platinum                yes                     some
# 2                    platinum                yes                     some
# 3                      silver                yes                     some
# 4                    platinum                yes                      yes
# 5                    platinum                yes                     some
# 6                    platinum                yes                       no
# 7                        gold                yes                       no
# 8                        gold                yes                       no
# 9                        gold                yes                   unsure
# 10                     unsure                yes                       no
# 11                     silver                yes                   unsure
# 12                       gold                yes                      yes
# 13                     unsure                yes                     some
# 14                   platinum                yes                       no
# 15                  certified                yes                      NaN
# 16                       gold                yes                       no
# 17                     silver                yes                   unsure
# 18                       gold                yes                       no
# 19                       gold                yes                       no
# 20                     unsure                 no                       no
# 21                   platinum                yes                       no
# 22                  certified                yes                      NaN
# 23                   platinum                yes                   unsure
# 24                       gold                yes                      yes
# 25                       gold                yes                   unsure
# 26                  certified                yes                   unsure
# 27                     unsure                yes                      yes
# 28                     unsure                yes                   unsure
# 29                  certified                yes                      NaN
# 30                     unsure                yes                   unsure
# 31                     unsure                yes                      yes
# 32                     unsure                yes                     some
# 33                     unsure                yes                       no
# 34                     silver                yes                      NaN
# 35                   platinum                yes                     some
# 36                     unsure             unsure                     some
# 37                       gold             unsure                   unsure
# 38                       gold                yes                      NaN
# 39                       gold                yes                   unsure
# 40                       gold                yes                   unsure
# 41                         no                 no                      NaN
# 42                  certified                yes                   unsure
# 43                     unsure             unsure                   unsure
# 44                     unsure                yes                   unsure
# 45                     unsure                yes                   unsure
# 46                       gold                yes                       no
# 47                       gold             unsure                       no
# 48                     unsure                yes                   unsure
# 49                       gold             unsure                   unsure
# 50                       gold             unsure                       no
# 51                     unsure             unsure                     some
#
#    percent_product_recycled_materials  \
# 0                                 100
# 1                                  61
# 2                              unsure
# 3                              unsure
# 4                                 > 0
# 5                              unsure
# 6                              unsure
# 7                              unsure
# 8                              unsure
# 9                              unsure
# 10                             unsure
# 11                             unsure
# 12                             unsure
# 13                             unsure
# 14                                NaN
# 15                                NaN
# 16                             unsure
# 17                             unsure
# 18                             unsure
# 19                             unsure
# 20                             unsure
# 21                             unsure
# 22                             unsure
# 23                                NaN
# 24                             unsure
# 25                             unsure
# 26                             unsure
# 27                                NaN
# 28                             unsure
# 29                                NaN
# 30                             unsure
# 31                                NaN
# 32                             unsure
# 33                             unsure
# 34                                NaN
# 35                             unsure
# 36                             unsure
# 37                             unsure
# 38                                NaN
# 39                             unsure
# 40                                NaN
# 41                                NaN
# 42                             unsure
# 43                                NaN
# 44                             unsure
# 45                             unsure
# 46                                NaN
# 47                                NaN
# 48                             unsure
# 49                             unsure
# 50                             unsure
# 51                             unsure
#
#                                reported_raw_materials  \
# 0                     cobalt, tantalum, tin, tungsten
# 1    graphite, silicon, gold, tantalum, tin, tungsten
# 2              lithium, gold, tantalum, tin, tungsten
# 3   cobalt, lithium, graphite, silicon, aluminum, ...
# 4   cobalt, lithium, silicon, gold, silver, alumin...
# 5   cobalt, silicon, silver, aluminum, tantalum, t...
# 6   cobalt, lithium, graphite, silicon, gold, silv...
# 7               gold, aluminum, tin, tungsten, copper
# 8                           cobalt, lithium, graphite
# 9      cobalt, silicon, gold, tantalum, tin, tungsten
# 10                                                NaN
# 11                                             unsure
# 12          cobalt, lithium, gold, tantalum, tungsten
# 13              cobalt, gold, tantalum, tin, tungsten
# 14                                                NaN
# 15                                                NaN
# 16  cobalt, lithium, graphite, silicon, gold, silv...
# 17  cobalt, silicon, gold, tantalum, tin, tungsten...
# 18  cobalt, lithium, graphite, silicon, gold, silv...
# 19  cobalt, lithium, graphite, silicon, gold, tant...
# 20                                                NaN
# 21  cobalt, lithium, silicon, tantalum, tin, tungs...
# 22                                                NaN
# 23                                                NaN
# 24                      gold, tantalum, tin, tungsten
# 25     cobalt, lithium, gold, tantalum, tin, tungsten
# 26                                                NaN
# 27                                                NaN
# 28     cobalt, lithium, gold, tantalum, tin, tungsten
# 29                                                NaN
# 30                      gold, tantalum, tin, tungsten
# 31                                                NaN
# 32                                                NaN
# 33  gold, tantalum, tin, tungsten, silicon wafers,...
# 34                                                NaN
# 35  cobalt, lithium, graphite, silicon, gold, silv...
# 36  cobalt, lithium, graphite, silicon, gold, silv...
# 37      cobalt, gold, tantalum, tin, tungsten, copper
# 38                                                NaN
# 39              cobalt, gold, tantalum, tin, tungsten
# 40                                                NaN
# 41                                                NaN
# 42                      gold, tantalum, tin, tungsten
# 43                                                NaN
# 44                      gold, tantalum, tin, tungsten
# 45                      gold, tantalum, tin, tungsten
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  cobalt, lithium, graphite, silicon, gold, silv...
# 50  cobalt, lithium, silicon, gold, tantalum, tung...
# 51  cobalt, lithium, graphite, silicon, gold, silv...
#
#    conflict_free_supply_change
# 0                     not sure
# 1                          yes
# 2                           no
# 3                       unsure
# 4                         some
# 5                           no
# 6                       unsure
# 7                           no
# 8                           no
# 9                          yes
# 10                          no
# 11                      unsure
# 12                         yes
# 13                          no
# 14                         NaN
# 15                         yes
# 16                          no
# 17                          no
# 18                          no
# 19                          no
# 20                          no
# 21                          no
# 22                         NaN
# 23                         NaN
# 24                      unsure
# 25                          no
# 26                         yes
# 27                         NaN
# 28                          no
# 29                         NaN
# 30                      unsure
# 31                         NaN
# 32                      unsure
# 33                          no
# 34                         NaN
# 35                         yes
# 36                          no
# 37                          no
# 38                         NaN
# 39                         yes
# 40                         NaN
# 41                         NaN
# 42                         yes
# 43                         NaN
# 44                          no
# 45                          no
# 46                         NaN
# 47                         NaN
# 48                         NaN
# 49                      unsure
# 50                          no
# 51                         yes
#
# [52 rows x 22 columns]

# %% [markdown]
# # GHG Emissions

# %% [markdown]
# We were able to find the total GHG emissions for most companies we found data for. Of the 51 companies, we couldn't find this information for the following three companies: Amazon, Palo Alto Networks, and Activision Blizzard. For Amazon, they listed some individual amounts of GHG emissions for various processes/items, but did not list any totals or GHG emissions for shipping, which is a major component of Amazon services.
#
# The average GHG emissions for the companies we found data for was 3002324.5515510207 metric tons of C02e. The two companies with the highest amount of GHG emissions were Apple and Samsung. The total GHG emissions for Samsung was 10 times that amount, with 29518000 metric tons of CO2e. Apple was the company with the second highest GHG emissions, with 22600000 metric tons of C02e, 7.5 times the average. On the other end, the company with the lowest total GHG emissions was Tokyo Electron Limited, with 169 metric tons of C02e.
#
# It's interesting to note that South Korea remains one of the most polluted countries in the world in terms of air quality. A 2017 study found that South Korea had the second worst air quality of all advanced nations of the Organization for Economic Cooperation and Development (Source: https://www.azocleantech.com/article.aspx?ArticleID=552).

# %%
# clean data
ghg_data = dataset[dataset['ghg_emissions_metric_tons'] != 'unsure']
ghg_data['ghg_emissions_metric_tons'] = ghg_data['ghg_emissions_metric_tons'].str.replace(',', '').astype(float)

# sort from lowest to highest GHG emissions
sorted_ghg_data = ghg_data.sort_values(by=['ghg_emissions_metric_tons'])
sorted_ghg_data
# Out:
# /home/nicole/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                        company headquarters_country  \
# 37                      Tokyo Electron Limited                Japan
# 30                                     Keyence                Japan
# 41                        Fidelity Investments        United States
# 20                                     Meituan                China
# 24                                      Intuit        United States
# 27                                  Servicenow        United States
# 29                                      PayPal        United States
# 18                                         AMD        United States
# 11                                    Broadcom        United States
# 48                                   Atlassian            Australia
# 43                                     NetEase                China
# 44                                    SK Hynix          South Korea
# 7                                       Nvidia        United States
# 23                                         SAP              Germany
# 36                                Lam Research        United States
# 31                                 Booking.com          Netherlands
# 1                                    Microsoft        United States
# 26             Automatic Data Processing (ADP)        United States
# 33                              Analog Devices        United States
# 28                           Applied Materials        United States
# 12                                       Cisco        United States
# 40                                      Fiserv        United States
# 45                              Block (Square)        United States
# 35                          Schneider Electric               France
# 14                                      Oracle        United States
# 15                                       Adobe        United States
# 21                                         IBM        United States
# 13                                ASML Holding          Netherlands
# 22                                  Salesforce        United States
# 25                                        Sony                Japan
# 34                                     Netflix        United States
# 19                           Texas Instruments        United States
# 3                                        Tesla        United States
# 32                      Jingdong Mall (JD.com)                China
# 38                                     Equinix        United States
# 16                                       Intel        United States
# 46                                        Uber        United States
# 17                                    Qualcomm        United States
# 49                             KLA Corporation        United States
# 8                                      Tencent                China
# 51                                     Foxconn               Taiwan
# 39                           Micron Technology        United States
# 6   Taiwan Semiconductor Manufacturing Company               Taiwan
# 2                              Meta (Facebook)        United States
# 0                            Alphabet (Google)        United States
# 10                                     Alibaba                China
# 50                    Marvell Technology, Inc.        United States
# 4                                        Apple        United States
# 9                                      Samsung          South Korea
#
#         usa_state  num_employees  net_worth  ghg_emissions_metric_tons  \
# 37            NaN          12742      29.00               1.690000e+02
# 30            NaN           6602      91.86               3.268000e+03
# 41  Massachusetts          65000      85.90               1.000000e+04
# 20            NaN          46662      27.77               1.078923e+04
# 24     California          14200     100.08               2.348100e+04
# 27     California          16881      85.55               2.433800e+04
# 29     California          26500      94.13               2.440000e+04
# 18     California          22500     156.65               2.991600e+04
# 11     California          20000     237.89               5.098800e+04
# 48            NaN           5752      23.99               7.020700e+04
# 43            NaN          18129      64.89               7.063303e+04
# 44            NaN          22254      56.08               9.976500e+04
# 7      California          22473     493.71               1.056210e+05
# 23            NaN         107415     165.53               1.100000e+05
# 36     California          14100      67.33               1.134820e+05
# 31            NaN          19400      85.39               1.187460e+05
# 1      Washington         182268    1893.24               1.237040e+05
# 26     New Jersey          58000      86.41               1.377140e+05
# 33  Massachusetts          24700      79.54               1.422090e+05
# 28     California          27000      94.31               1.513000e+05
# 12     California          79500     173.31               1.744940e+05
# 40      Wisconsin          44000      61.54               1.914050e+05
# 45     California           8521      46.23               2.479000e+05
# 35            NaN         166025      74.34               2.940510e+05
# 14          Texas         132000     178.87               3.693000e+05
# 15     California          25988     183.56               5.541257e+05
# 21       New York         282100     127.00               8.801880e+05
# 13            NaN          32016     219.21               8.839000e+05
# 22     California          73541     158.87               1.096000e+06
# 25            NaN         109700      45.00               1.392868e+06
# 34     California          12135      83.36               1.540000e+06
# 19          Texas          31000     154.57               1.920000e+06
# 3           Texas          70757     734.97               1.954000e+06
# 32            NaN         310000     149.30               2.275936e+06
# 38     California          10944      59.54               2.307600e+06
# 16     California         121100     171.78               2.890000e+06
# 46     California          29300      45.64               3.239552e+06
# 17     California          45000     146.24               3.943605e+06
# 49     California          11300      50.07               4.834000e+06
# 8             NaN         112771     431.30               5.111000e+06
# 51            NaN        1290000    5990.00               5.519742e+06
# 39          Idaho          40000      75.86               7.141289e+06
# 6             NaN          56831     410.00               7.430000e+06
# 2      California          71970     517.69               7.550000e+06
# 0      California         150028    1453.76               9.071847e+06
# 10            NaN         251462     237.72               9.514000e+06
# 50       Delaware           6729      46.80               1.124837e+07
# 4      California         154000    2223.03               2.260000e+07
# 9             NaN         287439     300.00               2.951800e+07
#
#    ghg_emissions_year water_withdrawal_cubic_meters  water_withdrawal_year  \
# 37               2021                          1195                    NaN
# 30               2020                        unsure                    NaN
# 41               2020                        unsure                    NaN
# 20               2020                        unsure                    NaN
# 24               2020                        unsure                 2020.0
# 27               2020                        unsure                 2020.0
# 29               2021                        293000                    NaN
# 18               2020                        151000                 2020.0
# 11               2021                   2501573.435                 2021.0
# 48               2021                        unsure                    NaN
# 43               2020                        unsure                 2020.0
# 44               2020                      95714000                    NaN
# 7                2021                        359901                 2019.0
# 23               2021                        765000                    NaN
# 36               2020                    1327458.28                 2021.0
# 31               2021                        unsure                    NaN
# 1                2021                          7657                 2020.0
# 26               2020                        unsure                    NaN
# 33               2020                        unsure                    NaN
# 28               2020                       2035000                 2021.0
# 12               2021                          2902                 2021.0
# 40               2021                        unsure                    NaN
# 45               2020                        unsure                 2020.0
# 35               2021                       2072263                 2020.0
# 14               2020                        unsure                    NaN
# 15               2019                        unsure                 2020.0
# 21               2020                        unsure                 2021.0
# 13               2021                       1041000                    NaN
# 22               2021                   492103.5319                 2021.0
# 25               2020                      18742665                    NaN
# 34               2021                        unsure                 2021.0
# 19               2020                      18560000                    NaN
# 3                2021                       2874904                 2020.0
# 32               2020                        unsure                    NaN
# 38               2021                        unsure                 2020.0
# 16               2020                      62736042                    NaN
# 46               2020                       1013210                    NaN
# 17               2021                    3514127.57                 2020.0
# 49               2020                        unsure                 2021.0
# 8                2021                    3635172.35                 2020.0
# 51               2020                        unsure                    NaN
# 39               2020                      55195350                    NaN
# 6                2020                      77000000                 2021.0
# 2                2020                       3726000                 2021.0
# 0                2021                     11365.225                 2021.0
# 10               2020                        unsure                 2021.0
# 50               2021                       9190000                    NaN
# 4                2020                    5850817.83                 2020.0
# 9                2020                        142294                    NaN
#
#    avg_annual_PUE  ... percent_renewable_energy money_in_renewables_USdollars  \
# 37            NaN  ...                       50                        unsure
# 30         unsure  ...                   unsure                        unsure
# 41            1.3  ...                      > 0                        unsure
# 20            NaN  ...                   unsure                        unsure
# 24         unsure  ...                      100                        unsure
# 27         unsure  ...                      100                        unsure
# 29           1.49  ...                       82                        unsure
# 18            NaN  ...                       71                        unsure
# 11            NaN  ...                   unsure                        unsure
# 48         unsure  ...                      100                        unsure
# 43            1.3  ...                     37.4                        unsure
# 44         unsure  ...                   unsure                        unsure
# 7             NaN  ...                   unsure                        unsure
# 23         unsure  ...                      100                        unsure
# 36            NaN  ...                       30                        unsure
# 31         unsure  ...                      100                        799808
# 1           1.125  ...                      100                     200000000
# 26           1.69  ...                        0                        unsure
# 33         unsure  ...                       53                        unsure
# 28         unsure  ...                      100                        unsure
# 12           1.05  ...                       85                     100000000
# 40           1.15  ...                     0.15                        unsure
# 45         unsure  ...                   unsure                      10000000
# 35            NaN  ...                     50.6                     156543450
# 14            1.5  ...                       59                        unsure
# 15         unsure  ...                      > 0                        unsure
# 21           1.67  ...                     59.3                        unsure
# 13            NaN  ...                       92                        unsure
# 22           1.39  ...                      100                        unsure
# 25         unsure  ...                   unsure                        unsure
# 34         unsure  ...                      100                        unsure
# 19            NaN  ...                    18.14                        unsure
# 3             NaN  ...                      100                        unsure
# 32            1.3  ...                   unsure                        unsure
# 38           1.48  ...                     80.1                    3700000000
# 16           1.06  ...                       82                      45000000
# 46         unsure  ...                       32                     800000000
# 17           1.18  ...                       50                      36000000
# 49            NaN  ...                       46                        unsure
# 8            1.25  ...                      > 0                        unsure
# 51            NaN  ...                    12.45                        unsure
# 39         unsure  ...                   unsure                    1000000000
# 6             NaN  ...                      7.6                      44000000
# 2             1.1  ...                      100                    7400000000
# 0             1.1  ...                      100                    3300000000
# 10           1.13  ...                   unsure                        unsure
# 50            NaN  ...                      1.3                        unsure
# 4          unsure  ...                      100                    4700000000
# 9             NaN  ...                      100                      not sure
#
#    waste_generated_metric_tons waste_generated_year  \
# 37                       14997               2021.0
# 30                         136               2020.0
# 41                      unsure                  NaN
# 20                      unsure                  NaN
# 24                 460.7781803               2020.0
# 27                      unsure                  NaN
# 29                      unsure                  NaN
# 18                         488               2020.0
# 11                    8688.108               2021.0
# 48                         124               2021.0
# 43                        6122               2020.0
# 44                      572134               2020.0
# 7                         2778               2021.0
# 23                         261               2021.0
# 36                        8306               2020.0
# 31                      unsure                  NaN
# 1                         3189               2021.0
# 26                      unsure                  NaN
# 33                        3042               2020.0
# 28                      8286.9               2020.0
# 12                        5863               2020.0
# 40                      unsure                  NaN
# 45                      unsure                  NaN
# 35                      136816               2021.0
# 14                 621.4229077               2020.0
# 15                      unsure                  NaN
# 21                       23000               2020.0
# 13                        5878               2021.0
# 22                      unsure                  NaN
# 25                   46594.823               2020.0
# 34                      unsure                  NaN
# 19                       41800               2020.0
# 3                    32877.282               2021.0
# 32                    25768.96               2020.0
# 38                      unsure                  NaN
# 16                  375574.482               2020.0
# 46                      unsure                  NaN
# 17                        2948               2021.0
# 49                      unsure                  NaN
# 8                       unsure                  NaN
# 51                      unsure                  NaN
# 39                  202286.633               2020.0
# 6                       unsure                  NaN
# 2                       unsure                  NaN
# 0                        28864               2021.0
# 10                      unsure                  NaN
# 50                      unsure                  NaN
# 4                    16556.122               2020.0
# 9                      1181741               2020.0
#
#    highest_leed_certification  ev_charging_ports carbon_neutral_shipments  \
# 37                       gold             unsure                   unsure
# 30                     unsure                yes                   unsure
# 41                         no                 no                      NaN
# 20                     unsure                 no                       no
# 24                       gold                yes                      yes
# 27                     unsure                yes                      yes
# 29                  certified                yes                      NaN
# 18                       gold                yes                       no
# 11                     silver                yes                   unsure
# 48                     unsure                yes                   unsure
# 43                     unsure             unsure                   unsure
# 44                     unsure                yes                   unsure
# 7                        gold                yes                       no
# 23                   platinum                yes                   unsure
# 36                     unsure             unsure                     some
# 31                     unsure                yes                      yes
# 1                    platinum                yes                     some
# 26                  certified                yes                   unsure
# 33                     unsure                yes                       no
# 28                     unsure                yes                   unsure
# 12                       gold                yes                      yes
# 40                       gold                yes                   unsure
# 45                     unsure                yes                   unsure
# 35                   platinum                yes                     some
# 14                   platinum                yes                       no
# 15                  certified                yes                      NaN
# 21                   platinum                yes                       no
# 13                     unsure                yes                     some
# 22                  certified                yes                      NaN
# 25                       gold                yes                   unsure
# 34                     silver                yes                      NaN
# 19                       gold                yes                       no
# 3                      silver                yes                     some
# 32                     unsure                yes                     some
# 38                       gold                yes                      NaN
# 16                       gold                yes                       no
# 46                       gold                yes                       no
# 17                     silver                yes                   unsure
# 49                       gold             unsure                   unsure
# 8                        gold                yes                       no
# 51                     unsure             unsure                     some
# 39                       gold                yes                   unsure
# 6                    platinum                yes                       no
# 2                    platinum                yes                     some
# 0                    platinum                yes                      yes
# 10                     unsure                yes                       no
# 50                       gold             unsure                       no
# 4                    platinum                yes                      yes
# 9                        gold                yes                   unsure
#
#    percent_product_recycled_materials  \
# 37                             unsure
# 30                             unsure
# 41                                NaN
# 20                             unsure
# 24                             unsure
# 27                                NaN
# 29                                NaN
# 18                             unsure
# 11                             unsure
# 48                             unsure
# 43                                NaN
# 44                             unsure
# 7                              unsure
# 23                                NaN
# 36                             unsure
# 31                                NaN
# 1                                  61
# 26                             unsure
# 33                             unsure
# 28                             unsure
# 12                             unsure
# 40                                NaN
# 45                             unsure
# 35                             unsure
# 14                                NaN
# 15                                NaN
# 21                             unsure
# 13                             unsure
# 22                             unsure
# 25                             unsure
# 34                                NaN
# 19                             unsure
# 3                              unsure
# 32                             unsure
# 38                                NaN
# 16                             unsure
# 46                                NaN
# 17                             unsure
# 49                             unsure
# 8                              unsure
# 51                             unsure
# 39                             unsure
# 6                              unsure
# 2                              unsure
# 0                                 100
# 10                             unsure
# 50                             unsure
# 4                                 > 0
# 9                              unsure
#
#                                reported_raw_materials  \
# 37      cobalt, gold, tantalum, tin, tungsten, copper
# 30                      gold, tantalum, tin, tungsten
# 41                                                NaN
# 20                                                NaN
# 24                      gold, tantalum, tin, tungsten
# 27                                                NaN
# 29                                                NaN
# 18  cobalt, lithium, graphite, silicon, gold, silv...
# 11                                             unsure
# 48                                                NaN
# 43                                                NaN
# 44                      gold, tantalum, tin, tungsten
# 7               gold, aluminum, tin, tungsten, copper
# 23                                                NaN
# 36  cobalt, lithium, graphite, silicon, gold, silv...
# 31                                                NaN
# 1    graphite, silicon, gold, tantalum, tin, tungsten
# 26                                                NaN
# 33  gold, tantalum, tin, tungsten, silicon wafers,...
# 28     cobalt, lithium, gold, tantalum, tin, tungsten
# 12          cobalt, lithium, gold, tantalum, tungsten
# 40                                                NaN
# 45                      gold, tantalum, tin, tungsten
# 35  cobalt, lithium, graphite, silicon, gold, silv...
# 14                                                NaN
# 15                                                NaN
# 21  cobalt, lithium, silicon, tantalum, tin, tungs...
# 13              cobalt, gold, tantalum, tin, tungsten
# 22                                                NaN
# 25     cobalt, lithium, gold, tantalum, tin, tungsten
# 34                                                NaN
# 19  cobalt, lithium, graphite, silicon, gold, tant...
# 3   cobalt, lithium, graphite, silicon, aluminum, ...
# 32                                                NaN
# 38                                                NaN
# 16  cobalt, lithium, graphite, silicon, gold, silv...
# 46                                                NaN
# 17  cobalt, silicon, gold, tantalum, tin, tungsten...
# 49  cobalt, lithium, graphite, silicon, gold, silv...
# 8                           cobalt, lithium, graphite
# 51  cobalt, lithium, graphite, silicon, gold, silv...
# 39              cobalt, gold, tantalum, tin, tungsten
# 6   cobalt, lithium, graphite, silicon, gold, silv...
# 2              lithium, gold, tantalum, tin, tungsten
# 0                     cobalt, tantalum, tin, tungsten
# 10                                                NaN
# 50  cobalt, lithium, silicon, gold, tantalum, tung...
# 4   cobalt, lithium, silicon, gold, silver, alumin...
# 9      cobalt, silicon, gold, tantalum, tin, tungsten
#
#    conflict_free_supply_change
# 37                          no
# 30                      unsure
# 41                         NaN
# 20                          no
# 24                      unsure
# 27                         NaN
# 29                         NaN
# 18                          no
# 11                      unsure
# 48                         NaN
# 43                         NaN
# 44                          no
# 7                           no
# 23                         NaN
# 36                          no
# 31                         NaN
# 1                          yes
# 26                         yes
# 33                          no
# 28                          no
# 12                         yes
# 40                         NaN
# 45                          no
# 35                         yes
# 14                         NaN
# 15                         yes
# 21                          no
# 13                          no
# 22                         NaN
# 25                          no
# 34                         NaN
# 19                          no
# 3                       unsure
# 32                      unsure
# 38                         NaN
# 16                          no
# 46                         NaN
# 17                          no
# 49                      unsure
# 8                           no
# 51                         yes
# 39                         yes
# 6                       unsure
# 2                           no
# 0                     not sure
# 10                          no
# 50                          no
# 4                         some
# 9                          yes
#
# [49 rows x 22 columns]

# %%
# get average GHG emissions
ghg_data["ghg_emissions_metric_tons"].mean()
# Out:
# 3002324.5515510207

# %%
x = sorted_ghg_data['company'][:5]
y = sorted_ghg_data['ghg_emissions_metric_tons'][:5]
plt.plot(x,y, '^', color='cornflowerblue', markersize=12)
plt.xlabel('Companies')
plt.ylabel('GHG Emissions (tons C02e)')
plt.title("Companies with lowest GHG Emissions")
plt.gcf().autofmt_xdate() 
plt.show()

# %%
x = sorted_ghg_data['company'][44:49]
y = sorted_ghg_data['ghg_emissions_metric_tons'][44:49]
plt.plot(x,y, '^', color='royalblue', markersize=12)
plt.xlabel('Companies')
plt.ylabel('GHG Emissions (tons C02e)')
plt.title("Companies with highest GHG Emissions")
plt.gcf().autofmt_xdate() 
plt.show()

# %% [markdown]
# ### GHG Emissions by country

# %%
groupings['headquarters_country']
groupings.first()
# Out:
#                                      company      usa_state num_employees  \
# headquarters_country
# Australia                          Atlassian            NaN          5752
# China                                Meituan            NaN         46662
# France                    Schneider Electric            NaN        166025
# Germany                                  SAP            NaN        107415
# Japan                 Tokyo Electron Limited            NaN         12742
# Netherlands                      Booking.com            NaN         19400
# South Korea                         SK Hynix            NaN         22254
# Taiwan                               Foxconn            NaN       1290000
# United States           Fidelity Investments  Massachusetts         65000
#
#                      net_worth  ghg_emissions_metric_tons ghg_emissions_year  \
# headquarters_country
# Australia                23.99                   70207.00               2021
# China                    27.77                   10789.23               2020
# France                   74.34                  294051.00               2021
# Germany                 165.53                  110000.00               2021
# Japan                    29.00                     169.00               2021
# Netherlands              85.39                  118746.00               2021
# South Korea              56.08                   99765.00               2020
# Taiwan                5,990.00                 5519742.00               2020
# United States            85.90                   10000.00               2020
#
#                      water_withdrawal_cubic_meters  water_withdrawal_year  \
# headquarters_country
# Australia                                   unsure                    NaN
# China                                       unsure                 2020.0
# France                                     2072263                 2020.0
# Germany                                     765000                    NaN
# Japan                                         1195                    NaN
# Netherlands                                 unsure                    NaN
# South Korea                               95714000                    NaN
# Taiwan                                      unsure                 2021.0
# United States                               unsure                 2020.0
#
#                      avg_annual_PUE percent_waste_diverted  ...  \
# headquarters_country                                        ...
# Australia                    unsure                 unsure  ...
# China                           1.3                 unsure  ...
# France                          NaN                    NaN  ...
# Germany                      unsure                 unsure  ...
# Japan                        unsure                 unsure  ...
# Netherlands                  unsure                 unsure  ...
# South Korea                  unsure                 unsure  ...
# Taiwan                          NaN                 unsure  ...
# United States                   1.3                     90  ...
#
#                      percent_renewable_energy money_in_renewables_USdollars  \
# headquarters_country
# Australia                                 100                        unsure
# China                                  unsure                        unsure
# France                                   50.6                     156543450
# Germany                                   100                        unsure
# Japan                                      50                        unsure
# Netherlands                               100                        799808
# South Korea                            unsure                        unsure
# Taiwan                                  12.45                        unsure
# United States                             > 0                        unsure
#
#                      waste_generated_metric_tons waste_generated_year  \
# headquarters_country
# Australia                                    124               2021.0
# China                                     unsure               2020.0
# France                                    136816               2021.0
# Germany                                      261               2021.0
# Japan                                      14997               2021.0
# Netherlands                               unsure               2021.0
# South Korea                               572134               2020.0
# Taiwan                                    unsure                  NaN
# United States                             unsure               2020.0
#
#                       highest_leed_certification ev_charging_ports  \
# headquarters_country
# Australia                                 unsure               yes
# China                                     unsure                no
# France                                  platinum               yes
# Germany                                 platinum               yes
# Japan                                       gold            unsure
# Netherlands                               unsure               yes
# South Korea                               unsure               yes
# Taiwan                                    unsure            unsure
# United States                                 no                no
#
#                      carbon_neutral_shipments  \
# headquarters_country
# Australia                              unsure
# China                                      no
# France                                   some
# Germany                                unsure
# Japan                                  unsure
# Netherlands                               yes
# South Korea                            unsure
# Taiwan                                   some
# United States                             yes
#
#                      percent_product_recycled_materials  \
# headquarters_country
# Australia                                        unsure
# China                                            unsure
# France                                           unsure
# Germany                                             NaN
# Japan                                            unsure
# Netherlands                                      unsure
# South Korea                                      unsure
# Taiwan                                           unsure
# United States                                    unsure
#
#                                                  reported_raw_materials  \
# headquarters_country
# Australia                                                           NaN
# China                                         cobalt, lithium, graphite
# France                cobalt, lithium, graphite, silicon, gold, silv...
# Germany                                                             NaN
# Japan                     cobalt, gold, tantalum, tin, tungsten, copper
# Netherlands                       cobalt, gold, tantalum, tin, tungsten
# South Korea                               gold, tantalum, tin, tungsten
# Taiwan                cobalt, lithium, graphite, silicon, gold, silv...
# United States                             gold, tantalum, tin, tungsten
#
#                      conflict_free_supply_change
# headquarters_country
# Australia                                    NaN
# China                                         no
# France                                       yes
# Germany                                      NaN
# Japan                                         no
# Netherlands                                   no
# South Korea                                   no
# Taiwan                                       yes
# United States                             unsure
#
# [9 rows x 21 columns]

# %%
groupings = sorted_ghg_data.groupby(['headquarters_country'])
countries = ['Australia', 'China', 'France', 'Germany', 'Japan', 'South Korea', 'Netherlands', 'Taiwan', 'United States']
emissions_avg = {}
for i in countries:
    emissions_avg.update({i:groupings.get_group(i)['ghg_emissions_metric_tons'].mean()})
        
    
emissions_avg = dict(sorted(emissions_avg.items(), key=lambda item: item[1]))
emissions_avg
# Out:
# {'Australia': 70207.0,
#  'Germany': 110000.0,
#  'France': 294051.0,
#  'Japan': 465435.0,
#  'Netherlands': 501323.0,
#  'United States': 2646588.408625,
#  'China': 3396471.59,
#  'Taiwan': 6474871.0,
#  'South Korea': 14808882.5}

# %%
plt.plot(emissions_avg.keys(), emissions_avg.values(), '^', color='cornflowerblue', markersize=12)
plt.xlabel('Countries')
plt.ylabel('Average GHG Emissions (tons C02e)')
plt.title("Avergae GHG Emissions by Country")
plt.gcf().autofmt_xdate() 
plt.show()

# %% [markdown]
# # Renewable Energy

# %% [markdown]
# We were able to find % renewable energy for 38 companies out of 51. Of these 38, 14 companies had 100% renewable energy usage. There were 6 companies that had zero or almost neglible percent renewable energy including: Tencent, Adobe, Automatic Data Processing (ADP), Fiserv, Fidelity Investments, and Activision Blizzard.

# %%
# clean data
dataset = dataset[dataset['percent_renewable_energy'].notna()]
re = dataset[dataset['percent_renewable_energy'] != 'unsure']

re = re[re["percent_renewable_energy"].str.contains(">") == False]
re['percent_renewable_energy'] = re['percent_renewable_energy'].str.replace(',', '').astype(float)

# sort from lowest to highest % renewable energy
sorted_re_data = re.sort_values(by=['percent_renewable_energy'])
sorted_re_data
# Out:
#                                        company headquarters_country  \
# 26             Automatic Data Processing (ADP)        United States
# 40                                      Fiserv        United States
# 50                    Marvell Technology, Inc.        United States
# 6   Taiwan Semiconductor Manufacturing Company               Taiwan
# 47                          Palo Alto Networks        United States
# 51                                     Foxconn               Taiwan
# 19                           Texas Instruments        United States
# 36                                Lam Research        United States
# 46                                        Uber        United States
# 43                                     NetEase                China
# 49                             KLA Corporation        United States
# 37                      Tokyo Electron Limited                Japan
# 17                                    Qualcomm        United States
# 35                          Schneider Electric               France
# 33                              Analog Devices        United States
# 14                                      Oracle        United States
# 21                                         IBM        United States
# 5                                       Amazon        United States
# 18                                         AMD        United States
# 38                                     Equinix        United States
# 16                                       Intel        United States
# 29                                      PayPal        United States
# 12                                       Cisco        United States
# 13                                ASML Holding          Netherlands
# 48                                   Atlassian            Australia
# 0                            Alphabet (Google)        United States
# 31                                 Booking.com          Netherlands
# 28                           Applied Materials        United States
# 27                                  Servicenow        United States
# 23                                         SAP              Germany
# 22                                  Salesforce        United States
# 9                                      Samsung          South Korea
# 4                                        Apple        United States
# 3                                        Tesla        United States
# 2                              Meta (Facebook)        United States
# 1                                    Microsoft        United States
# 34                                     Netflix        United States
# 24                                      Intuit        United States
#
#         usa_state  num_employees  net_worth ghg_emissions_metric_tons  \
# 26     New Jersey          58000      86.41                    137714
# 40      Wisconsin          44000      61.54                    191405
# 50       Delaware           6729      46.80                  11248370
# 6             NaN          56831     410.00                   7430000
# 47     California          11098      42.98                    unsure
# 51            NaN        1290000    5990.00                   5519742
# 19          Texas          31000     154.57                   1920000
# 36     California          14100      67.33                    113482
# 46     California          29300      45.64                   3239552
# 43            NaN          18129      64.89                  70633.03
# 49     California          11300      50.07                   4834000
# 37            NaN          12742      29.00                       169
# 17     California          45000     146.24                   3943605
# 35            NaN         166025      74.34                    294051
# 33  Massachusetts          24700      79.54                    142209
# 14          Texas         132000     178.87                    369300
# 21       New York         282100     127.00                    880188
# 5      Washington         170000    1091.91                    unsure
# 18     California          22500     156.65                     29916
# 38     California          10944      59.54                   2307600
# 16     California         121100     171.78                   2890000
# 29     California          26500      94.13                     24400
# 12     California          79500     173.31                    174494
# 13            NaN          32016     219.21                    883900
# 48            NaN           5752      23.99                     70207
# 0      California         150028    1453.76                 9071847.4
# 31            NaN          19400      85.39                    118746
# 28     California          27000      94.31                    151300
# 27     California          16881      85.55                     24338
# 23            NaN         107415     165.53                    110000
# 22     California          73541     158.87                   1096000
# 9             NaN         287439     300.00                  29518000
# 4      California         154000    2223.03                  22600000
# 3           Texas          70757     734.97                   1954000
# 2      California          71970     517.69                   7550000
# 1      Washington         182268    1893.24                    123704
# 34     California          12135      83.36                   1540000
# 24     California          14200     100.08                     23481
#
#    ghg_emissions_year water_withdrawal_cubic_meters  water_withdrawal_year  \
# 26               2020                        unsure                    NaN
# 40               2021                        unsure                    NaN
# 50               2021                       9190000                    NaN
# 6                2020                      77000000                 2021.0
# 47                NaN                        unsure                    NaN
# 51               2020                        unsure                    NaN
# 19               2020                      18560000                    NaN
# 36               2020                    1327458.28                 2021.0
# 46               2020                       1013210                    NaN
# 43               2020                        unsure                 2020.0
# 49               2020                        unsure                 2021.0
# 37               2021                          1195                    NaN
# 17               2021                    3514127.57                 2020.0
# 35               2021                       2072263                 2020.0
# 33               2020                        unsure                    NaN
# 14               2020                        unsure                    NaN
# 21               2020                        unsure                 2021.0
# 5              unsure                     480000000                 2020.0
# 18               2020                        151000                 2020.0
# 38               2021                        unsure                 2020.0
# 16               2020                      62736042                    NaN
# 29               2021                        293000                    NaN
# 12               2021                          2902                 2021.0
# 13               2021                       1041000                    NaN
# 48               2021                        unsure                    NaN
# 0                2021                     11365.225                 2021.0
# 31               2021                        unsure                    NaN
# 28               2020                       2035000                 2021.0
# 27               2020                        unsure                 2020.0
# 23               2021                        765000                    NaN
# 22               2021                   492103.5319                 2021.0
# 9                2020                        142294                    NaN
# 4                2020                    5850817.83                 2020.0
# 3                2021                       2874904                 2020.0
# 2                2020                       3726000                 2021.0
# 1                2021                          7657                 2020.0
# 34               2021                        unsure                 2021.0
# 24               2020                        unsure                 2020.0
#
#    avg_annual_PUE  ... percent_renewable_energy money_in_renewables_USdollars  \
# 26           1.69  ...                     0.00                        unsure
# 40           1.15  ...                     0.15                        unsure
# 50            NaN  ...                     1.30                        unsure
# 6             NaN  ...                     7.60                      44000000
# 47            NaN  ...                    10.00                        unsure
# 51            NaN  ...                    12.45                        unsure
# 19            NaN  ...                    18.14                        unsure
# 36            NaN  ...                    30.00                        unsure
# 46         unsure  ...                    32.00                     800000000
# 43            1.3  ...                    37.40                        unsure
# 49            NaN  ...                    46.00                        unsure
# 37            NaN  ...                    50.00                        unsure
# 17           1.18  ...                    50.00                      36000000
# 35            NaN  ...                    50.60                     156543450
# 33         unsure  ...                    53.00                        unsure
# 14            1.5  ...                    59.00                        unsure
# 21           1.67  ...                    59.30                        unsure
# 5             1.7  ...                    65.00                        unsure
# 18            NaN  ...                    71.00                        unsure
# 38           1.48  ...                    80.10                    3700000000
# 16           1.06  ...                    82.00                      45000000
# 29           1.49  ...                    82.00                        unsure
# 12           1.05  ...                    85.00                     100000000
# 13            NaN  ...                    92.00                        unsure
# 48         unsure  ...                   100.00                        unsure
# 0             1.1  ...                   100.00                    3300000000
# 31         unsure  ...                   100.00                        799808
# 28         unsure  ...                   100.00                        unsure
# 27         unsure  ...                   100.00                        unsure
# 23         unsure  ...                   100.00                        unsure
# 22           1.39  ...                   100.00                        unsure
# 9             NaN  ...                   100.00                      not sure
# 4          unsure  ...                   100.00                    4700000000
# 3             NaN  ...                   100.00                        unsure
# 2             1.1  ...                   100.00                    7400000000
# 1           1.125  ...                   100.00                     200000000
# 34         unsure  ...                   100.00                        unsure
# 24         unsure  ...                   100.00                        unsure
#
#     waste_generated_metric_tons waste_generated_year  \
# 26                       unsure                  NaN
# 40                       unsure                  NaN
# 50                       unsure                  NaN
# 6                        unsure                  NaN
# 47                       unsure                  NaN
# 51                       unsure                  NaN
# 19                        41800               2020.0
# 36                         8306               2020.0
# 46                       unsure                  NaN
# 43                         6122               2020.0
# 49                       unsure                  NaN
# 37                        14997               2021.0
# 17                         2948               2021.0
# 35                       136816               2021.0
# 33                         3042               2020.0
# 14                  621.4229077               2020.0
# 21                        23000               2020.0
# 5                    272155.422               2020.0
# 18                          488               2020.0
# 38                       unsure                  NaN
# 16                   375574.482               2020.0
# 29                       unsure                  NaN
# 12                         5863               2020.0
# 13                         5878               2021.0
# 48                          124               2021.0
# 0                         28864               2021.0
# 31                       unsure                  NaN
# 28                       8286.9               2020.0
# 27                       unsure                  NaN
# 23                          261               2021.0
# 22                       unsure                  NaN
# 9                       1181741               2020.0
# 4                     16556.122               2020.0
# 3                     32877.282               2021.0
# 2                        unsure                  NaN
# 1                          3189               2021.0
# 34                       unsure                  NaN
# 24                  460.7781803               2020.0
#
#    highest_leed_certification  ev_charging_ports carbon_neutral_shipments  \
# 26                  certified                yes                   unsure
# 40                       gold                yes                   unsure
# 50                       gold             unsure                       no
# 6                    platinum                yes                       no
# 47                       gold             unsure                       no
# 51                     unsure             unsure                     some
# 19                       gold                yes                       no
# 36                     unsure             unsure                     some
# 46                       gold                yes                       no
# 43                     unsure             unsure                   unsure
# 49                       gold             unsure                   unsure
# 37                       gold             unsure                   unsure
# 17                     silver                yes                   unsure
# 35                   platinum                yes                     some
# 33                     unsure                yes                       no
# 14                   platinum                yes                       no
# 21                   platinum                yes                       no
# 5                    platinum                yes                     some
# 18                       gold                yes                       no
# 38                       gold                yes                      NaN
# 16                       gold                yes                       no
# 29                  certified                yes                      NaN
# 12                       gold                yes                      yes
# 13                     unsure                yes                     some
# 48                     unsure                yes                   unsure
# 0                    platinum                yes                      yes
# 31                     unsure                yes                      yes
# 28                     unsure                yes                   unsure
# 27                     unsure                yes                      yes
# 23                   platinum                yes                   unsure
# 22                  certified                yes                      NaN
# 9                        gold                yes                   unsure
# 4                    platinum                yes                      yes
# 3                      silver                yes                     some
# 2                    platinum                yes                     some
# 1                    platinum                yes                     some
# 34                     silver                yes                      NaN
# 24                       gold                yes                      yes
#
#    percent_product_recycled_materials  \
# 26                             unsure
# 40                                NaN
# 50                             unsure
# 6                              unsure
# 47                                NaN
# 51                             unsure
# 19                             unsure
# 36                             unsure
# 46                                NaN
# 43                                NaN
# 49                             unsure
# 37                             unsure
# 17                             unsure
# 35                             unsure
# 33                             unsure
# 14                                NaN
# 21                             unsure
# 5                              unsure
# 18                             unsure
# 38                                NaN
# 16                             unsure
# 29                                NaN
# 12                             unsure
# 13                             unsure
# 48                             unsure
# 0                                 100
# 31                                NaN
# 28                             unsure
# 27                                NaN
# 23                                NaN
# 22                             unsure
# 9                              unsure
# 4                                 > 0
# 3                              unsure
# 2                              unsure
# 1                                  61
# 34                                NaN
# 24                             unsure
#
#                                reported_raw_materials  \
# 26                                                NaN
# 40                                                NaN
# 50  cobalt, lithium, silicon, gold, tantalum, tung...
# 6   cobalt, lithium, graphite, silicon, gold, silv...
# 47                                                NaN
# 51  cobalt, lithium, graphite, silicon, gold, silv...
# 19  cobalt, lithium, graphite, silicon, gold, tant...
# 36  cobalt, lithium, graphite, silicon, gold, silv...
# 46                                                NaN
# 43                                                NaN
# 49  cobalt, lithium, graphite, silicon, gold, silv...
# 37      cobalt, gold, tantalum, tin, tungsten, copper
# 17  cobalt, silicon, gold, tantalum, tin, tungsten...
# 35  cobalt, lithium, graphite, silicon, gold, silv...
# 33  gold, tantalum, tin, tungsten, silicon wafers,...
# 14                                                NaN
# 21  cobalt, lithium, silicon, tantalum, tin, tungs...
# 5   cobalt, silicon, silver, aluminum, tantalum, t...
# 18  cobalt, lithium, graphite, silicon, gold, silv...
# 38                                                NaN
# 16  cobalt, lithium, graphite, silicon, gold, silv...
# 29                                                NaN
# 12          cobalt, lithium, gold, tantalum, tungsten
# 13              cobalt, gold, tantalum, tin, tungsten
# 48                                                NaN
# 0                     cobalt, tantalum, tin, tungsten
# 31                                                NaN
# 28     cobalt, lithium, gold, tantalum, tin, tungsten
# 27                                                NaN
# 23                                                NaN
# 22                                                NaN
# 9      cobalt, silicon, gold, tantalum, tin, tungsten
# 4   cobalt, lithium, silicon, gold, silver, alumin...
# 3   cobalt, lithium, graphite, silicon, aluminum, ...
# 2              lithium, gold, tantalum, tin, tungsten
# 1    graphite, silicon, gold, tantalum, tin, tungsten
# 34                                                NaN
# 24                      gold, tantalum, tin, tungsten
#
#    conflict_free_supply_change
# 26                         yes
# 40                         NaN
# 50                          no
# 6                       unsure
# 47                         NaN
# 51                         yes
# 19                          no
# 36                          no
# 46                         NaN
# 43                         NaN
# 49                      unsure
# 37                          no
# 17                          no
# 35                         yes
# 33                          no
# 14                         NaN
# 21                          no
# 5                           no
# 18                          no
# 38                         NaN
# 16                          no
# 29                         NaN
# 12                         yes
# 13                          no
# 48                         NaN
# 0                     not sure
# 31                         NaN
# 28                          no
# 27                         NaN
# 23                         NaN
# 22                         NaN
# 9                          yes
# 4                         some
# 3                       unsure
# 2                           no
# 1                          yes
# 34                         NaN
# 24                      unsure
#
# [38 rows x 22 columns]

# %%
out = pd.cut(sorted_re_data['percent_renewable_energy'], bins=[0, 20, 40, 60, 80, 100], include_lowest=True)
ax = out.value_counts(sort=False).plot.bar(rot=0, color=['lightskyblue', 'mediumblue', 'cornflowerblue', 'royalblue', 'lightblue'], figsize=(6,4))
ax.set_title('Frequency for % of Renewable Energy', size=16)
ax.set_ylabel('Count', size=12)
ax.set_xlabel('% Renewable Energy', size=12)

plt.show()

# %% [markdown]
# # Water Withdrawal

# %% [markdown]
# We were able to find amount of water withdrawn in cubic meters for 29 companies. The average amount of water withdrawn was 29274344.87 cubic meters. The companies with the lowest water withdrawn include Tokyo Electron Limited, Cisco, Microsoft, Google, and Samsung. The companies with the highest water withdrawn include Intel, SK Hynix, and Amazon. Amazon had the highest water withdrawn with 480000000 cubic meters, about 16 times the average.

# %%
# clean data
dataset = dataset[dataset['water_withdrawal_cubic_meters'].notna()]
water = dataset[dataset['water_withdrawal_cubic_meters'] != 'unsure']

water['water_withdrawal_cubic_meters'] = water['water_withdrawal_cubic_meters'].str.replace(',', '').astype(float)

# sort from lowest to highest cubic meters of water withdrawal 
sorted_water_data = water.sort_values(by=['water_withdrawal_cubic_meters'])
sorted_water_data
# Out:
# /home/nicole/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                        company headquarters_country  \
# 37                      Tokyo Electron Limited                Japan
# 12                                       Cisco        United States
# 1                                    Microsoft        United States
# 0                            Alphabet (Google)        United States
# 9                                      Samsung          South Korea
# 18                                         AMD        United States
# 29                                      PayPal        United States
# 7                                       Nvidia        United States
# 22                                  Salesforce        United States
# 23                                         SAP              Germany
# 46                                        Uber        United States
# 13                                ASML Holding          Netherlands
# 36                                Lam Research        United States
# 28                           Applied Materials        United States
# 35                          Schneider Electric               France
# 11                                    Broadcom        United States
# 3                                        Tesla        United States
# 17                                    Qualcomm        United States
# 8                                      Tencent                China
# 2                              Meta (Facebook)        United States
# 4                                        Apple        United States
# 50                    Marvell Technology, Inc.        United States
# 19                           Texas Instruments        United States
# 25                                        Sony                Japan
# 39                           Micron Technology        United States
# 16                                       Intel        United States
# 6   Taiwan Semiconductor Manufacturing Company               Taiwan
# 44                                    SK Hynix          South Korea
# 5                                       Amazon        United States
#
#      usa_state  num_employees  net_worth ghg_emissions_metric_tons  \
# 37         NaN          12742      29.00                       169
# 12  California          79500     173.31                    174494
# 1   Washington         182268    1893.24                    123704
# 0   California         150028    1453.76                 9071847.4
# 9          NaN         287439     300.00                  29518000
# 18  California          22500     156.65                     29916
# 29  California          26500      94.13                     24400
# 7   California          22473     493.71                    105621
# 22  California          73541     158.87                   1096000
# 23         NaN         107415     165.53                    110000
# 46  California          29300      45.64                   3239552
# 13         NaN          32016     219.21                    883900
# 36  California          14100      67.33                    113482
# 28  California          27000      94.31                    151300
# 35         NaN         166025      74.34                    294051
# 11  California          20000     237.89                     50988
# 3        Texas          70757     734.97                   1954000
# 17  California          45000     146.24                   3943605
# 8          NaN         112771     431.30                   5111000
# 2   California          71970     517.69                   7550000
# 4   California         154000    2223.03                  22600000
# 50    Delaware           6729      46.80                  11248370
# 19       Texas          31000     154.57                   1920000
# 25         NaN         109700      45.00                   1392868
# 39       Idaho          40000      75.86                   7141289
# 16  California         121100     171.78                   2890000
# 6          NaN          56831     410.00                   7430000
# 44         NaN          22254      56.08                     99765
# 5   Washington         170000    1091.91                    unsure
#
#    ghg_emissions_year  water_withdrawal_cubic_meters  water_withdrawal_year  \
# 37               2021                   1.195000e+03                    NaN
# 12               2021                   2.902000e+03                 2021.0
# 1                2021                   7.657000e+03                 2020.0
# 0                2021                   1.136523e+04                 2021.0
# 9                2020                   1.422940e+05                    NaN
# 18               2020                   1.510000e+05                 2020.0
# 29               2021                   2.930000e+05                    NaN
# 7                2021                   3.599010e+05                 2019.0
# 22               2021                   4.921035e+05                 2021.0
# 23               2021                   7.650000e+05                    NaN
# 46               2020                   1.013210e+06                    NaN
# 13               2021                   1.041000e+06                    NaN
# 36               2020                   1.327458e+06                 2021.0
# 28               2020                   2.035000e+06                 2021.0
# 35               2021                   2.072263e+06                 2020.0
# 11               2021                   2.501573e+06                 2021.0
# 3                2021                   2.874904e+06                 2020.0
# 17               2021                   3.514128e+06                 2020.0
# 8                2021                   3.635172e+06                 2020.0
# 2                2020                   3.726000e+06                 2021.0
# 4                2020                   5.850818e+06                 2020.0
# 50               2021                   9.190000e+06                    NaN
# 19               2020                   1.856000e+07                    NaN
# 25               2020                   1.874266e+07                    NaN
# 39               2020                   5.519535e+07                    NaN
# 16               2020                   6.273604e+07                    NaN
# 6                2020                   7.700000e+07                 2021.0
# 44               2020                   9.571400e+07                    NaN
# 5              unsure                   4.800000e+08                 2020.0
#
#    avg_annual_PUE  ... percent_renewable_energy money_in_renewables_USdollars  \
# 37            NaN  ...                       50                        unsure
# 12           1.05  ...                       85                     100000000
# 1           1.125  ...                      100                     200000000
# 0             1.1  ...                      100                    3300000000
# 9             NaN  ...                      100                      not sure
# 18            NaN  ...                       71                        unsure
# 29           1.49  ...                       82                        unsure
# 7             NaN  ...                   unsure                        unsure
# 22           1.39  ...                      100                        unsure
# 23         unsure  ...                      100                        unsure
# 46         unsure  ...                       32                     800000000
# 13            NaN  ...                       92                        unsure
# 36            NaN  ...                       30                        unsure
# 28         unsure  ...                      100                        unsure
# 35            NaN  ...                     50.6                     156543450
# 11            NaN  ...                   unsure                        unsure
# 3             NaN  ...                      100                        unsure
# 17           1.18  ...                       50                      36000000
# 8            1.25  ...                      > 0                        unsure
# 2             1.1  ...                      100                    7400000000
# 4          unsure  ...                      100                    4700000000
# 50            NaN  ...                      1.3                        unsure
# 19            NaN  ...                    18.14                        unsure
# 25         unsure  ...                   unsure                        unsure
# 39         unsure  ...                   unsure                    1000000000
# 16           1.06  ...                       82                      45000000
# 6             NaN  ...                      7.6                      44000000
# 44         unsure  ...                   unsure                        unsure
# 5             1.7  ...                       65                        unsure
#
#    waste_generated_metric_tons waste_generated_year  \
# 37                       14997               2021.0
# 12                        5863               2020.0
# 1                         3189               2021.0
# 0                        28864               2021.0
# 9                      1181741               2020.0
# 18                         488               2020.0
# 29                      unsure                  NaN
# 7                         2778               2021.0
# 22                      unsure                  NaN
# 23                         261               2021.0
# 46                      unsure                  NaN
# 13                        5878               2021.0
# 36                        8306               2020.0
# 28                      8286.9               2020.0
# 35                      136816               2021.0
# 11                    8688.108               2021.0
# 3                    32877.282               2021.0
# 17                        2948               2021.0
# 8                       unsure                  NaN
# 2                       unsure                  NaN
# 4                    16556.122               2020.0
# 50                      unsure                  NaN
# 19                       41800               2020.0
# 25                   46594.823               2020.0
# 39                  202286.633               2020.0
# 16                  375574.482               2020.0
# 6                       unsure                  NaN
# 44                      572134               2020.0
# 5                   272155.422               2020.0
#
#    highest_leed_certification  ev_charging_ports carbon_neutral_shipments  \
# 37                       gold             unsure                   unsure
# 12                       gold                yes                      yes
# 1                    platinum                yes                     some
# 0                    platinum                yes                      yes
# 9                        gold                yes                   unsure
# 18                       gold                yes                       no
# 29                  certified                yes                      NaN
# 7                        gold                yes                       no
# 22                  certified                yes                      NaN
# 23                   platinum                yes                   unsure
# 46                       gold                yes                       no
# 13                     unsure                yes                     some
# 36                     unsure             unsure                     some
# 28                     unsure                yes                   unsure
# 35                   platinum                yes                     some
# 11                     silver                yes                   unsure
# 3                      silver                yes                     some
# 17                     silver                yes                   unsure
# 8                        gold                yes                       no
# 2                    platinum                yes                     some
# 4                    platinum                yes                      yes
# 50                       gold             unsure                       no
# 19                       gold                yes                       no
# 25                       gold                yes                   unsure
# 39                       gold                yes                   unsure
# 16                       gold                yes                       no
# 6                    platinum                yes                       no
# 44                     unsure                yes                   unsure
# 5                    platinum                yes                     some
#
#    percent_product_recycled_materials  \
# 37                             unsure
# 12                             unsure
# 1                                  61
# 0                                 100
# 9                              unsure
# 18                             unsure
# 29                                NaN
# 7                              unsure
# 22                             unsure
# 23                                NaN
# 46                                NaN
# 13                             unsure
# 36                             unsure
# 28                             unsure
# 35                             unsure
# 11                             unsure
# 3                              unsure
# 17                             unsure
# 8                              unsure
# 2                              unsure
# 4                                 > 0
# 50                             unsure
# 19                             unsure
# 25                             unsure
# 39                             unsure
# 16                             unsure
# 6                              unsure
# 44                             unsure
# 5                              unsure
#
#                                reported_raw_materials  \
# 37      cobalt, gold, tantalum, tin, tungsten, copper
# 12          cobalt, lithium, gold, tantalum, tungsten
# 1    graphite, silicon, gold, tantalum, tin, tungsten
# 0                     cobalt, tantalum, tin, tungsten
# 9      cobalt, silicon, gold, tantalum, tin, tungsten
# 18  cobalt, lithium, graphite, silicon, gold, silv...
# 29                                                NaN
# 7               gold, aluminum, tin, tungsten, copper
# 22                                                NaN
# 23                                                NaN
# 46                                                NaN
# 13              cobalt, gold, tantalum, tin, tungsten
# 36  cobalt, lithium, graphite, silicon, gold, silv...
# 28     cobalt, lithium, gold, tantalum, tin, tungsten
# 35  cobalt, lithium, graphite, silicon, gold, silv...
# 11                                             unsure
# 3   cobalt, lithium, graphite, silicon, aluminum, ...
# 17  cobalt, silicon, gold, tantalum, tin, tungsten...
# 8                           cobalt, lithium, graphite
# 2              lithium, gold, tantalum, tin, tungsten
# 4   cobalt, lithium, silicon, gold, silver, alumin...
# 50  cobalt, lithium, silicon, gold, tantalum, tung...
# 19  cobalt, lithium, graphite, silicon, gold, tant...
# 25     cobalt, lithium, gold, tantalum, tin, tungsten
# 39              cobalt, gold, tantalum, tin, tungsten
# 16  cobalt, lithium, graphite, silicon, gold, silv...
# 6   cobalt, lithium, graphite, silicon, gold, silv...
# 44                      gold, tantalum, tin, tungsten
# 5   cobalt, silicon, silver, aluminum, tantalum, t...
#
#    conflict_free_supply_change
# 37                          no
# 12                         yes
# 1                          yes
# 0                     not sure
# 9                          yes
# 18                          no
# 29                         NaN
# 7                           no
# 22                         NaN
# 23                         NaN
# 46                         NaN
# 13                          no
# 36                          no
# 28                          no
# 35                         yes
# 11                      unsure
# 3                       unsure
# 17                          no
# 8                           no
# 2                           no
# 4                         some
# 50                          no
# 19                          no
# 25                          no
# 39                         yes
# 16                          no
# 6                       unsure
# 44                          no
# 5                           no
#
# [29 rows x 22 columns]

# %%
# get average water withdrawn
water["water_withdrawal_cubic_meters"].mean()
# Out:
# 29274344.869720694

# %%
x = sorted_water_data['company'][:5]
y = sorted_water_data['water_withdrawal_cubic_meters'][:5]
plt.plot(x,y, '^', color='cornflowerblue', markersize=12)
plt.xlabel('Companies')
plt.ylabel('Water Withdrawal (tons C02e)')
plt.title("Companies with lowest Water Withdrawal")
plt.gcf().autofmt_xdate() 
plt.show()

# %%
x = sorted_water_data['company'][-5:]
y = sorted_water_data['water_withdrawal_cubic_meters'][-5:]
plt.plot(x,y, '^', color='mediumblue', markersize=12)
plt.xlabel('Companies')
plt.ylabel('Water Withdrawal (tons C02e)')
plt.title("Companies with highest Water Withdrawal")
plt.gcf().autofmt_xdate() 
plt.show()

# %% [markdown]
# # LEED Certification

# %%
def label_function(val):
    return f'{val / 100 * len(dataset):.0f}\n{val:.0f}%'

# %%
leed_pi = dataset.groupby('highest_leed_certification').size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 15},
                                  colors=['dodgerblue', 'lightblue', 'lightcyan', 'mediumblue','cornflowerblue', 'lightskyblue'], figsize=(20,10))

leed_pi.set_title('Highest LEED Certification for Companies', size=22)
leed_pi
# Out:
# <AxesSubplot:title={'center':'Highest LEED Certification for Companies'}, ylabel='None'>
